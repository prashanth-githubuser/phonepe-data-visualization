# %%
import os

path = 'C:\\Users\\Prashanth M\\Desktop\\Untitled Folder\\Data set\\git\\pulse\\data\\aggregated\\transaction\\country\\india\\state\\'
agg_trans_st_dir = os.listdir(path)
agg_trans_st_dir
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
import pandas as pd
import json

agg_trans_dict = {'State':[],
                  'Year':[],
                  'Quater':[],
                  'Transacion_type':[],
                  'Transacion_count':[],
                  'Transacion_amount':[]}

for i in agg_trans_st_dir:
  st_path = path+i+'/'
  st_year = os.listdir(st_path)
  for j in st_year:   
    st_year_path = st_path+j+'/'
    st_year_dir = os.listdir(st_year_path)
    for k in st_year_dir:
      json_path = st_year_path+k
      jsonData = open(json_path, 'r')
      Data = json.load(jsonData)
      for x in Data['data']['transactionData']:
                    Name = x['name']
                    count = x['paymentInstruments'][0]['count']
                    amount = x['paymentInstruments'][0]['amount']
                    agg_trans_dict['Transacion_type'].append(Name)
                    agg_trans_dict['Transacion_count'].append(count)
                    agg_trans_dict['Transacion_amount'].append(amount)
                    agg_trans_dict['State'].append(i)
                    agg_trans_dict['Year'].append(j)
                    agg_trans_dict['Quater'].append('Q'+k.strip('.json'))

agg_trans_df = pd.DataFrame(agg_trans_dict)
#agg_trans_df

# %%
os.getcwd()
# Out:
# 'd:\\Python\\Project\\Zomato\\zomato'

# %%
agg_trans_df.to_csv('AggTransByStates.csv',index=False)

# %% [markdown]
# ### By Brand

# %%
path = "C:\\Users\\Prashanth M\\Desktop\\Untitled Folder\\Data set\\git\\pulse\data\\aggregated\\user\\country\\india\\state\\"
state_dir =os.listdir(path)

user_dict = {'State': [], 'Year': [], 'Quater': [], 'Brand': [],
    'Brand_count': [], 'Brand_percentage': []}

for i in state_dir:
  state_path = path+i+'/'
  year_dir  = os.listdir(st_path)
  for j in year_dir:
    year_path = state_path+j+'/'
    file_dir = os.listdir(year_path)
    for k in file_dir:
      file_path = year_path+k
      jsonFile = open(file_path,'r')
      Data = json.load(jsonFile)
      try:
        for x in Data['data']['usersByDevice']:
          brand = x['brand']
          count = x['count']
          percentage = x['percentage']

          user_dict['Brand'].append(brand)
          user_dict['Brand_count'].append(count)
          user_dict['Brand_percentage'].append(percentage)
          user_dict['State'].append(i)
          user_dict['Year'].append(j)
          user_dict['Quater'].append('Q'+k.strip('.json'))
      except TypeError:
        pass
      
userByBrand_df = pd.DataFrame(user_dict)

userByBrand_df
# Out:
#                           State  Year Quater    Brand  Brand_count  \
# 0     andaman-&-nicobar-islands  2018     Q1   Xiaomi         1665
# 1     andaman-&-nicobar-islands  2018     Q1  Samsung         1445
# 2     andaman-&-nicobar-islands  2018     Q1     Vivo          982
# 3     andaman-&-nicobar-islands  2018     Q1     Oppo          501
# 4     andaman-&-nicobar-islands  2018     Q1  OnePlus          332
# ...                         ...   ...    ...      ...          ...
# 6727                west-bengal  2022     Q1   Lenovo       330017
# 6728                west-bengal  2022     Q1  Infinix       284678
# 6729                west-bengal  2022     Q1     Asus       280347
# 6730                west-bengal  2022     Q1    Apple       277752
# 6731                west-bengal  2022     Q1   Others      2196334
#
#       Brand_percentage
# 0             0.247033
# 1             0.214392
# 2             0.145697
# 3             0.074332
# 4             0.049258
# ...

# %%
userByBrand_df.to_csv('AggUserByBrand.csv',index=False)

# %% [markdown]
# Map transaction by states

# %%
path = "C:\\Users\Prashanth M\\Desktop\\Untitled Folder\\Data set\\git\\pulse\\data\\map\\transaction\\hover\\country\\india\\state\\"


state_dir =os.listdir(path)


map_trans_dict = {'State': [], 'Year': [], 'Quater': [], 'District': [],
    'Transaction_count': [], 'Transaction_amount': []}

for i in state_dir:
  state_path = path+i+'/'
  year_dir  = os.listdir(st_path)
  for j in year_dir:
    year_path = state_path+j+'/'
    file_dir = os.listdir(year_path)
    for k in file_dir:
      file_path = year_path+k
      jsonFile = open(file_path,'r')
      Data = json.load(jsonFile)
      try:
        for x in Data['data']["hoverDataList"]:
          district = x['name']
          trans_count = x['metric'][0]['count']
          trans_amount = x['metric'][0]['amount']
          map_trans_dict['District'].append(district)
          map_trans_dict['Transaction_count'].append(trans_count)
          map_trans_dict['Transaction_amount'].append(trans_amount)
          map_trans_dict['State'].append(i)
          map_trans_dict['Year'].append(j)
          map_trans_dict['Quater'].append('Q'+k.strip('.json'))
      except TypeError:
        pass
      
mapTransByDist_df = pd.DataFrame(map_trans_dict)

mapTransByDist_df
# Out:
#                            State  Year Quater  \
# 0      andaman-&-nicobar-islands  2018     Q1
# 1      andaman-&-nicobar-islands  2018     Q1
# 2      andaman-&-nicobar-islands  2018     Q1
# 3      andaman-&-nicobar-islands  2018     Q2
# 4      andaman-&-nicobar-islands  2018     Q2
# ...                          ...   ...    ...
# 14631                west-bengal  2022     Q4
# 14632                west-bengal  2022     Q4
# 14633                west-bengal  2022     Q4
# 14634                west-bengal  2022     Q4
# 14635                west-bengal  2022     Q4
#
#                                 District  Transaction_count  \
# 0      north and middle andaman district                442
# 1                 south andaman district               5688
# 2                      nicobars district                528
# 3      north and middle andaman district                825
# 4                 south andaman district               9395
# ...

# %%
mapTransByDist_df.to_csv('mapTransByDistrict.csv',index=False)

# %% [markdown]
# By States

# %%
path= "C:\\Users\\Prashanth M\\Desktop\\Untitled Folder\\Data set\\git\\pulse\\data\\map\\user\\hover\\country\\india\\state\\"
state_dir =os.listdir(path)

mapUserDictReg = {'State': [], 'Year': [], 'Quater': [], 'District': [],
    'Registered_user': [], 'App_opening': []}

for i in state_dir:
  state_path = path+i+'/'
  year_dir  = os.listdir(st_path)
  for j in year_dir:
    year_path = state_path+j+'/'
    file_dir = os.listdir(year_path)
    for k in file_dir:
      file_path = year_path+k
      jsonFile = open(file_path,'r')
      Data = json.load(jsonFile)
      try:
        for x in Data['data']["hoverData"]:
          district = x
          registeredUser =  Data['data']["hoverData"][x]["registeredUsers"]
          app_opening = Data['data']["hoverData"][x]["appOpens"]
          mapUserDictReg['District'].append(district)
          mapUserDictReg['Registered_user'].append(registeredUser)
          mapUserDictReg['App_opening'].append(app_opening)
          mapUserDictReg['State'].append(i)
          mapUserDictReg['Year'].append(j)
          mapUserDictReg['Quater'].append('Q'+k.strip('.json'))
      except TypeError:
        pass
      
mapUserByDistReg_df = pd.DataFrame(mapUserDictReg)

mapUserByDistReg_df
# Out:
#                            State  Year Quater  \
# 0      andaman-&-nicobar-islands  2018     Q1
# 1      andaman-&-nicobar-islands  2018     Q1
# 2      andaman-&-nicobar-islands  2018     Q1
# 3      andaman-&-nicobar-islands  2018     Q2
# 4      andaman-&-nicobar-islands  2018     Q2
# ...                          ...   ...    ...
# 14635                west-bengal  2022     Q4
# 14636                west-bengal  2022     Q4
# 14637                west-bengal  2022     Q4
# 14638                west-bengal  2022     Q4
# 14639                west-bengal  2022     Q4
#
#                                 District  Registered_user  App_opening
# 0      north and middle andaman district              632            0
# 1                 south andaman district             5846            0
# 2                      nicobars district              262            0
# 3      north and middle andaman district              911            0
# ...

# %%
mapUserByDistReg_df.to_csv('mapUserByDistReg.csv',index=False)

# %% [markdown]
# top transaction

# %%
path = "C:\\Users\\Prashanth M\\Desktop\\Untitled Folder\\Data set\\git\\pulse\\data\\top\\transaction\\country\\india\\state\\"

# %%
state_dir =os.listdir(path)

mapUserDictReg = {'State': [], 'Year': [], 'Quater': [], 'District': [],
    'Registered_user': [], 'App_opening': []}

for i in state_dir:
  state_path = path+i+'/'
  year_dir  = os.listdir(st_path)
  for j in year_dir:
    year_path = state_path+j+'/'
    file_dir = os.listdir(year_path)
    for k in file_dir:
      file_path = year_path+k
      jsonFile = open(file_path,'r')
      Data = json.load(jsonFile)
      try:
        for x in Data['data']["hoverData"]:
          district = x
          registeredUser =  Data['data']["hoverData"][x]["registeredUsers"]
          app_opening = Data['data']["hoverData"][x]["appOpens"]
          mapUserDictReg['District'].append(district)
          mapUserDictReg['Registered_user'].append(registeredUser)
          mapUserDictReg['App_opening'].append(app_opening)
          mapUserDictReg['State'].append(i)
          mapUserDictReg['Year'].append(j)
          mapUserDictReg['Quater'].append('Q'+k.strip('.json'))
      except TypeError:
        pass
      
mapUserByDistReg_df = pd.DataFrame(mapUserDictReg)

mapUserByDistReg_df
